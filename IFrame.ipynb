# %%
from IPython.display import IFrame

# %%
IFrame("http://bl.ocks.org/jfost00/raw/37b84bde59636c9b530a/", "900", "800")
# Out:
#         <iframe
#             width="900"
#             height="800"
#             src="http://bl.ocks.org/jfost00/raw/37b84bde59636c9b530a/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
