# %% [markdown]
# # Plotting and Visualization

# %% [markdown]
# ## Plotting examples from http://matplotlib.org/api/pyplot_api.html

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-poster')

# %%
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('A simple chirp');

# %%
plt.plot(np.random.randn(50).cumsum())

# %%
plt.hist(np.random.randn(50))
# Out:
# (array([  1.,   1.,   3.,   4.,   7.,   8.,  12.,   5.,   6.,   3.]),
#  array([-3.11443529, -2.60268315, -2.09093101, -1.57917887, -1.06742674,
#         -0.5556746 , -0.04392246,  0.46782967,  0.97958181,  1.49133395,
#          2.00308608]),
#  <a list of 10 Patch objects>)

# %%
plt.bar(np.arange(5), np.absolute(np.random.randn(5)), tick_label = ['a', 'b', 'c', 'd', 'e'])
# Out:
# <Container object of 5 artists>
